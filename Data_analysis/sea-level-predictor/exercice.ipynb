# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress
import numpy as np

# %%
df = pd.read_csv('epa-sea-level.csv')

# %%
df
# Out:
#      Year  CSIRO Adjusted Sea Level  Lower Error Bound  Upper Error Bound  \
# 0    1880                  0.000000          -0.952756           0.952756
# 1    1881                  0.220472          -0.732283           1.173228
# 2    1882                 -0.440945          -1.346457           0.464567
# 3    1883                 -0.232283          -1.129921           0.665354
# 4    1884                  0.590551          -0.283465           1.464567
# ..    ...                       ...                ...                ...
# 129  2009                  8.586614           8.311024           8.862205
# 130  2010                  8.901575           8.618110           9.185039
# 131  2011                  8.964567           8.661417           9.267717
# 132  2012                  9.326772           8.992126           9.661417
# 133  2013                  8.980315           8.622047           9.338583
#
#      NOAA Adjusted Sea Level
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ..                       ...
# 129                 8.046354
# 130                 8.122973
# 131                 8.053065
# 132                 8.457058
# 133                 8.546648
#
# [134 rows x 5 columns]

# %%
plt.scatter(x=df['Year'], y=df['CSIRO Adjusted Sea Level'], s=5)

# %%
ext = df['Year'].copy()
ext.loc[len(ext)] = 2050
ext
# Out:
# 0      1880
# 1      1881
# 2      1882
# 3      1883
# 4      1884
#        ...
# 130    2010
# 131    2011
# 132    2012
# 133    2013
# 134    2050
# Name: Year, Length: 135, dtype: int64

# %%
slope, intercept, r_value, p_value, std_err = linregress(df['Year'], df['CSIRO Adjusted Sea Level'])
y_pred = intercept + (slope * ext)
plt.scatter(x=df['Year'], y=df['CSIRO Adjusted Sea Level'], s=5)
plt.plot(ext, y_pred, color='red')

# %%
slope2, intercept2, r_value2, p_value2, std_err2 = linregress(df.loc[df['Year'] >= 2000,'Year'], df.loc[df['Year'] >= 2000,'CSIRO Adjusted Sea Level'])
y_pred2 = intercept2 + (slope2 * ext)
plt.scatter(x=df['Year'], y=df['CSIRO Adjusted Sea Level'], s=5)
plt.plot(ext, y_pred, color='red')
plt.plot(ext, y_pred2, color='green')
plt.title('Rise in Sea Level')
plt.xlabel('Year')
plt.ylabel('Sea Level (inches)')
# Out:
# Text(0, 0.5, 'Sea Level (inches)')
